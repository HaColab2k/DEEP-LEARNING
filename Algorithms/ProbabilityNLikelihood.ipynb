# %%
import pandas as pd 
df=pd.read_csv("bell_curve.csv")

# %%
df.head()
# Out:
#    Student  Score  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        1     74         NaN         NaN         NaN         NaN         NaN
# 1        2     65         NaN         NaN         NaN         NaN         NaN
# 2        3     88         NaN         NaN         NaN         NaN         NaN
# 3        4     53         NaN         NaN         NaN         NaN         NaN
# 4        5     67         NaN         NaN         NaN         NaN         NaN
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2         NaN         NaN         NaN
# 3         NaN         NaN         NaN
# 4         NaN         NaN         NaN

# %%
df.dropna(axis='columns')
# Out:
#      Student  Score
# 0          1     74
# 1          2     65
# 2          3     88
# 3          4     53
# 4          5     67
# ..       ...    ...
# 195      196     78
# 196      197     74
# 197      198     49
# 198      199     75
# 199      200     81
#
# [200 rows x 2 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import statistics
Student = df['Student'].to_numpy()
Score = df['Score'].to_numpy()

# mean = statistics.mean(x_axis)
# sd = statistics.stdev(x_axis)
# print("mean :",mean)
# print("Stadard deviation :",sd)
plt.plot(Student, Score)
plt.show()
